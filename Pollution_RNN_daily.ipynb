# %% [markdown]
# <a href="https://colab.research.google.com/github/puraminy/mini_proj2/blob/master/Pollution_RNN_daily.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load DATA

# %% [markdown]
# #### Data Main Source
# #####https://archive.ics.uci.edu/ml/datasets/Beijing+PM2.5+Data

# %%
# !git clone "https://github.com/puraminy/mini_proj2"
# Out:
# fatal: destination path 'mini_proj2' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd

dataset_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"

#github = "https://raw.githubusercontent.com/puraminy/mini_proj2/master/polution.csv"

github = "mini_proj2/polution.csv"

c=pd.read_csv(github)
data=np.asarray(c)
print(data)
np.shape(data)
# Out:
# [[0.12977867 0.35294122 0.24590163 ... 0.00229001 0.         0.        ]
#  [0.14889336 0.36764708 0.24590163 ... 0.00381099 0.         0.        ]
#  [0.15995975 0.42647061 0.22950819 ... 0.00533197 0.         0.        ]
#  ...
#  [0.01006036 0.2647059  0.26229507 ... 0.40558836 0.         0.        ]
#  [0.01006036 0.2647059  0.26229507 ... 0.41399646 0.         0.        ]
#  [0.00804829 0.2647059  0.24590163 ... 0.42086649 0.         0.        ]]
# (43799, 8)

# %%
from matplotlib import pyplot
values = c.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(c.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %% [markdown]
# # Preparing Time Series

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot as plt
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# load dataset
def create_data(n_hours = 24, n_train = 10000):
  dataset = read_csv('mini_proj2/polution.csv', header=0)
  values = dataset.values
  
  print(np.shape(values))
  # integer encode direction
  encoder = LabelEncoder()
  values[:,4] = encoder.fit_transform(values[:,4])
  # ensure all data is float
  values = values.astype('float32')
  # normalize features
  # scaler = MinMaxScaler(feature_range=(0, 1))
  scaled = values # scaler.fit_transform(values)
  # specify the number of lag hours
  # n_hours = 24
  n_features = 8 
  # frame as supervised learning
  reframed = series_to_supervised(scaled, n_hours, 1)

 # print(reframed[:2])
 # print(reframed.shape)

  # split into train and test sets
  values = reframed.values
   #365 * 24
  train = values[:n_train, :]
  test = values[n_train:, :]
  # split into input and outputs
  n_obs = n_hours * n_features
  train_X, train_y = train[:, :n_obs], train[:, -n_features]

  test_X, test_y = test[:, :n_obs], test[:, -n_features]
  print(train_X.shape, len(train_X), train_y.shape)
  # reshape input to be 3D [samples, timesteps, features]
    
  train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
  test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
  print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
  
  return train_X,train_y, test_X, test_y

# %% [markdown]
# # Split Train & Test Data

# %%
def create_data2(days = 24, n_train = 10000, step =1):
  c=pd.read_csv(github)
  data=np.asarray(c)
  n_hours = 24*days
  print(np.shape(data))
  
  print(data.shape[0])
  n_test = data.shape[0]-n_train
  train = data[:n_train, :]
  test = data[n_train:n_train+n_test, :]

  train_X = np.zeros([n_train-n_hours, days, 8])
  for i in range (n_train-n_hours):
    for j in range (days):
      train_X[i, j, :] = train[i+24*j,:]
  train_y = train[n_hours:, 0]
  
  test_X = np.zeros([n_test-n_hours, days, 8])
  for i in range (n_test-n_hours):
    for j in range (days):
      test_X[i, j, :] = test[i+24*j,:]
  test_y = test[n_hours:, 0]
  

  print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
  
  return train_X,train_y, test_X, test_y

create_data2(days = 24, n_train = 10000, step =1)
# Out:
# (43799, 8)
# 43799
# (9424, 24, 8) (9424,) (33223, 24, 8) (33223,)
# (array([[[0.12977867, 0.35294122, 0.24590163, ..., 0.00229001,
#           0.        , 0.        ],
#          [0.09054326, 0.48529413, 0.21311474, ..., 0.09930788,
#           0.14814815, 0.        ],
#          [0.07947686, 0.38235295, 0.1147541 , ..., 0.02672819,
#           0.        , 0.        ],
#          ...,
#          [0.04929577, 0.33823532, 0.24590163, ..., 0.29330945,
#           0.        , 0.        ],
#          [0.        , 0.36764708, 0.27868852, ..., 0.01069811,
#           0.        , 0.        ],
#          [0.        , 0.22058827, 0.22950819, ..., 0.24062209,
#           0.        , 0.        ]],
#
#         [[0.14889336, 0.36764708, 0.24590163, ..., 0.00381099,
#           0.        , 0.        ],
#          [0.06338028, 0.47058827, 0.21311474, ..., 0.10465693,
#           0.18518519, 0.        ],
#          [0.0583501 , 0.35294122, 0.16393442, ..., 0.03665727,
#           0.        , 0.        ],
#          ...,
#          [0.02414487, 0.33823532, 0.18032786, ..., 0.00075194,
#           0.        , 0.        ],
#          [0.        , 0.38235295, 0.1967213 , ..., 0.        ,
#           0.        , 0.        ],
#          [0.        , 0.22058827, 0.21311474, ..., 0.25590023,
#           0.        , 0.        ]],
#
#         [[0.15995975, 0.42647061, 0.22950819, ..., 0.00533197,
#           0.        , 0.        ],
#          [0.06539235, 0.47058827, 0.1967213 , ..., 0.11152697,
#           0.22222222, 0.        ],
#          [0.0251509 , 0.33823532, 0.14754099, ..., 0.05041443,
#           0.        , 0.        ],
#          ...,
#          [0.02313883, 0.33823532, 0.22950819, ..., 0.00763907,
#           0.        , 0.        ],
#          [0.        , 0.38235295, 0.18032786, ..., 0.00229001,
#           0.        , 0.        ],
#          [0.        , 0.23529413, 0.21311474, ..., 0.2765274 ,
#           0.        , 0.        ]],
#
#         ...,
#
#         [[0.0110664 , 0.2647059 , 0.26229507, ..., 0.03209434,
#           0.        , 0.        ],
#          [0.01408451, 0.2647059 , 0.32786885, ..., 0.28112453,
#           0.        , 0.        ],
#          [0.02313883, 0.29411766, 0.42622948, ..., 0.05651543,
#           0.        , 0.        ],
#          ...,
#          [0.09255533, 0.41176474, 0.45901638, ..., 0.00075194,
#           0.        , 0.        ],
#          [0.43963781, 0.5147059 , 0.44262293, ..., 0.00229001,
#           0.        , 0.        ],
#          [0.43259555, 0.55882353, 0.3934426 , ..., 0.00229001,
#           0.        , 0.        ]],
#
#         [[0.04225352, 0.2647059 , 0.27868852, ..., 0.0458515 ,
#           0.        , 0.        ],
#          [0.01609658, 0.2647059 , 0.34426227, ..., 0.29640266,
#           0.        , 0.        ],
#          [0.01710262, 0.30882356, 0.44262293, ..., 0.06873451,
#           0.        , 0.        ],
#          ...,
#          [0.12776659, 0.44117647, 0.49180326, ..., 0.00229001,
#           0.        , 0.        ],
#          [0.47987926, 0.52941179, 0.44262293, ..., 0.00229001,
#           0.        , 0.        ],
#          [0.45472836, 0.54411769, 0.42622948, ..., 0.00534906,
#           0.        , 0.        ]],
#
#         [[0.01509054, 0.25000003, 0.29508194, ..., 0.05807059,
#           0.        , 0.        ],
#          [0.01609658, 0.2647059 , 0.34426227, ..., 0.31015983,
#           0.        , 0.        ],
#          [0.02112676, 0.30882356, 0.44262293, ..., 0.0786636 ,
#           0.        , 0.        ],
#          ...,
#          [0.12776659, 0.44117647, 0.50819671, ..., 0.00534906,
#           0.        , 0.        ],
#          [0.51307845, 0.5147059 , 0.45901638, ..., 0.00534906,
#           0.        , 0.        ],
#          [0.4919517 , 0.54411769, 0.42622948, ..., 0.00075194,
#           0.        , 0.        ]]]),
#  array([0.        , 0.        , 0.        , ..., 0.32394364, 0.36217302,
#         0.37826961]),
#  array([[[0.37122735, 0.5147059 , 0.44262293, ..., 0.00075194,
#           0.        , 0.        ],
#          [0.39939636, 0.54411769, 0.45901638, ..., 0.00075194,
#           0.        , 0.        ],
#          [0.02816901, 0.30882356, 0.49180326, ..., 0.02137914,
#           0.        , 0.        ],
#          ...,
#          [0.02112676, 0.30882356, 0.47540981, ..., 0.50494754,
#           0.        , 0.        ],
#          [0.02716298, 0.39705884, 0.49180326, ..., 0.02824917,
#           0.        , 0.        ],
#          [0.09657948, 0.44117647, 0.59016395, ..., 0.02519012,
#           0.        , 0.        ]],
#
#         [[0.3561368 , 0.5147059 , 0.42622948, ..., 0.00229001,
#           0.        , 0.        ],
#          [0.38933599, 0.55882353, 0.44262293, ..., 0.00227292,
#           0.        , 0.        ],
#          [0.02414487, 0.30882356, 0.49180326, ..., 0.02978723,
#           0.        , 0.        ],
#          ...,
#          [0.01911469, 0.30882356, 0.45901638, ..., 0.52174664,
#           0.        , 0.        ],
#          [0.02716298, 0.39705884, 0.47540981, ..., 0.0351192 ,
#           0.        , 0.        ],
#          [0.09657948, 0.41176474, 0.57377046, ..., 0.03206016,
#           0.        , 0.        ]],
#
#         [[0.33702213, 0.5147059 , 0.3934426 , ..., 0.00229001,
#           0.        , 0.        ],
#          [0.39839032, 0.54411769, 0.40983605, ..., 0.00229001,
#           0.        , 0.        ],
#          [0.02112676, 0.33823532, 0.42622948, ..., 0.00075194,
#           0.        , 0.        ],
#          ...,
#          [0.01911469, 0.32352942, 0.45901638, ..., 0.53396571,
#           0.        , 0.        ],
#          [0.04426559, 0.39705884, 0.45901638, ..., 0.04198924,
#           0.        , 0.        ],
#          [0.09054326, 0.44117647, 0.54098356, ..., 0.00075194,
#           0.        , 0.        ]],
#
#         ...,
#
#         [[0.01710262, 0.33823532, 0.32786885, ..., 0.10694695,
#           0.        , 0.        ],
#          [0.        , 0.42647061, 0.24590163, ..., 0.0037939 ,
#           0.        , 0.        ],
#          [0.35814887, 0.48529413, 0.29508194, ..., 0.01069811,
#           0.        , 0.        ],
#          ...,
#          [0.17605633, 0.39705884, 0.36065573, ..., 0.00075194,
#           0.        , 0.        ],
#          [0.11267605, 0.41176474, 0.32786885, ..., 0.0037939 ,
#           0.        , 0.        ],
#          [0.02615694, 0.42647061, 0.3934426 , ..., 0.02137914,
#           0.        , 0.        ]],
#
#         [[0.01810865, 0.32352942, 0.32786885, ..., 0.12070411,
#           0.        , 0.        ],
#          [0.        , 0.42647061, 0.22950819, ..., 0.00531488,
#           0.        , 0.        ],
#          [0.36921528, 0.48529413, 0.29508194, ..., 0.01375716,
#           0.        , 0.        ],
#          ...,
#          [0.2947686 , 0.39705884, 0.32786885, ..., 0.00227292,
#           0.        , 0.        ],
#          [0.12877263, 0.39705884, 0.3114754 , ..., 0.00456293,
#           0.        , 0.        ],
#          [0.02012072, 0.41176474, 0.37704915, ..., 0.03665727,
#           0.        , 0.        ]],
#
#         [[0.01609658, 0.33823532, 0.3114754 , ..., 0.1291122 ,
#           0.        , 0.        ],
#          [0.        , 0.42647061, 0.22950819, ..., 0.00075194,
#           0.        , 0.        ],
#          [0.36317906, 0.48529413, 0.29508194, ..., 0.00075194,
#           0.        , 0.        ],
#          ...,
#          [0.32595572, 0.44117647, 0.34426227, ..., 0.0037939 ,
#           0.        , 0.        ],
#          [0.16498993, 0.41176474, 0.26229507, ..., 0.00458002,
#           0.        , 0.        ],
#          [0.00804829, 0.27941179, 0.34426227, ..., 0.05345638,
#           0.        , 0.        ]]]),
#  array([0.        , 0.        , 0.        , ..., 0.01006036, 0.01006036,
#         0.00804829]))

# %% [markdown]
# # Model

# %%
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU, SimpleRNN

import tensorflow as tf
# GPU Processing
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at:{}'.format(device_name))

def create_model(cell_type = "normal", optimizer = 'adam'):
  if cell_type == "lstm":
    model = Sequential()
    model.add(LSTM(70, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1, activation='linear'))
  elif cell_type == "gru":
    model = Sequential()
    model.add(GRU(70, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1, activation='linear'))
  elif cell_type == "rnn":
    model = Sequential()
    model.add(SimpleRNN(70, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1, activation='linear'))
  else:
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(10))
#     model.add(Dense(20)) 
    model.add(Dense(10)) 
    model.add(Dense(1, activation='linear'))
  
  model.name = 'model_' + cell_type + '_' + optimizer
  if optimizer == 'rmsprop':
    optimizer = tf.train.RMSPropOptimizer(0.001)
    
#   model.compile(loss='mae', optimizer=optimizer)
  
  model.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mse'])

  return model

n_train = 10000
days = 7

train_X,train_y, test_X, test_y = create_data2(days, n_train=n_train)

model_normal_adam = create_model(optimizer='adam') #0
model_normal_sgd = create_model(optimizer='sgd') #1
model_normal_rmsprop = create_model(optimizer='rmsprop') #2

model_lstm_adam = create_model("lstm", 'adam') #3
model_lstm_sgd = create_model("lstm",'sgd') #4
model_lstm_rmsprop = create_model("lstm",'rmsprop') #5


model_gru_adam = create_model("gru", 'adam') #6
model_gru_sgd = create_model("gru", 'sgd') #7
model_gru_rmsprop = create_model("gru", 'rmsprop') #8


model_rnn_adam = create_model("rnn", 'adam') #9
model_rnn_sgd = create_model("rnn", 'sgd') #10
model_rnn_rmsprop = create_model("rnn", 'rmsprop') #11


models = [model_normal_adam, model_normal_sgd, model_normal_rmsprop,
          model_lstm_adam, model_lstm_sgd, model_lstm_rmsprop,
          model_gru_adam,model_gru_sgd, model_gru_rmsprop,
          model_rnn_adam, model_rnn_sgd, model_rnn_rmsprop]


Run = [0]*len(models)
Run[0] = 1
Run[3] = 1
Run[6] = 1
Run[9] = 1
EPOCHS =[20]*len(models)
model_index = 0

legends = []
silent = False

for model in models:

  # fit network
  model_name = model.name
  print(f"##################### Model {model_name} Hours {n_hours} ##################")
  print("\n")

  if not Run[model_index]:
    print("Skipped")
    model_index+=1
    continue

  legends.append(model_name)

  history = model.fit(train_X, train_y, 
                      epochs=EPOCHS[model_index], batch_size=72, 
#                       validation_data=(test_X, test_y), 
                      validation_split=0.1,
                      verbose=1, shuffle=True)
  # plot history
  if not silent: 
    plt.figure(0)
    plt.plot(history.history['loss'], label='train')
    plt.xlabel("Num of Epochs")
    plt.ylabel("Loss")
    plt.title("Training")
    plt.legend(legends)

    plt.figure(1)
    plt.plot(history.history['val_loss'], label='test')
    plt.xlabel("Num of Epochs")
    plt.ylabel("Loss")
    plt.title("Test")
    plt.legend(legends)

  test_predictions = model.predict(test_X).flatten()
  test_loss = model.evaluate(test_X, test_y)

  if not silent:
    plt.figure(num=model_index+2, figsize=(20, 3), dpi=80, facecolor='w', edgecolor='k')
    plt.title(f"Prediction of {model_name}")
    plt.xlabel('Time')
    plt.ylabel('normalized value')
    plt.legend(('Original', 'Predicted'), loc='upper right')
    plt.plot(data[:,0], 'bo')
    plt.plot(np.concatenate([data[:n_train,0],test_predictions]), 'go', alpha=1)
    plt.legend(('Original', 'Predicted'), loc='upper right')
    plt.savefig(model_name)

  model_index +=1


plt.show()
# Out:
# Found GPU at:/device:GPU:0
# (43799, 8)
# 43799
# (9832, 7, 8) (9832,) (33631, 7, 8) (33631,)
# ##################### Model model_normal_adam Hours 168 ##################
#
#
# Train on 8848 samples, validate on 984 samples
# Epoch 1/20
# 8848/8848 [==============================] - 3s 306us/step - loss: 0.0574 - mean_squared_error: 0.0574 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 2/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 3/20
# 8848/8848 [==============================] - 1s 79us/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 4/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 5/20
# 8848/8848 [==============================] - 1s 80us/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 6/20
# 8848/8848 [==============================] - 1s 80us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 7/20
# 8848/8848 [==============================] - 1s 79us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 8/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 9/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 10/20
# 8848/8848 [==============================] - 1s 78us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 11/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 12/20
# 8848/8848 [==============================] - 1s 84us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 13/20
# 8848/8848 [==============================] - 1s 79us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 14/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 15/20
# 8848/8848 [==============================] - 1s 79us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 16/20
# 8848/8848 [==============================] - 1s 79us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 17/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 18/20
# 8848/8848 [==============================] - 1s 81us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 19/20
# 8848/8848 [==============================] - 1s 80us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 20/20
# 8848/8848 [==============================] - 1s 77us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# 33631/33631 [==============================] - 2s 62us/step
# ##################### Model model_normal_sgd Hours 168 ##################
#
#
# Skipped
# ##################### Model model_normal_rmsprop Hours 168 ##################
#
#
# Skipped
# ##################### Model model_lstm_adam Hours 168 ##################
#
#
# Train on 8848 samples, validate on 984 samples
# Epoch 1/20
# 8848/8848 [==============================] - 5s 612us/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 2/20
# 8848/8848 [==============================] - 3s 362us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 3/20
# 8848/8848 [==============================] - 3s 360us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 4/20
# 8848/8848 [==============================] - 3s 359us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 5/20
# 8848/8848 [==============================] - 3s 358us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 6/20
# 8848/8848 [==============================] - 3s 360us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 7/20
# 8848/8848 [==============================] - 3s 363us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 8/20
# 8848/8848 [==============================] - 3s 362us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 9/20
# 8848/8848 [==============================] - 3s 369us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 10/20
# 8848/8848 [==============================] - 3s 362us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 11/20
# 8848/8848 [==============================] - 3s 357us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 12/20
# 8848/8848 [==============================] - 3s 356us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 13/20
# 8848/8848 [==============================] - 4s 414us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 14/20
# 8848/8848 [==============================] - 4s 453us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 15/20
# 8848/8848 [==============================] - 3s 362us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 16/20
# 8848/8848 [==============================] - 3s 360us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 17/20
# 8848/8848 [==============================] - 3s 362us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 18/20
# 8848/8848 [==============================] - 3s 361us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 19/20
# 8848/8848 [==============================] - 3s 360us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 20/20
# 8848/8848 [==============================] - 3s 359us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# 33631/33631 [==============================] - 10s 310us/step
# ##################### Model model_lstm_sgd Hours 168 ##################
#
#
# Skipped
# ##################### Model model_lstm_rmsprop Hours 168 ##################
#
#
# Skipped
# ##################### Model model_gru_adam Hours 168 ##################
#
#
# Train on 8848 samples, validate on 984 samples
# Epoch 1/20
# 8848/8848 [==============================] - 5s 572us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 2/20
# 8848/8848 [==============================] - 3s 312us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 3/20
# 8848/8848 [==============================] - 3s 314us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 4/20
# 8848/8848 [==============================] - 3s 316us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 5/20
# 8848/8848 [==============================] - 3s 311us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 6/20
# 8848/8848 [==============================] - 3s 314us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 7/20
# 8848/8848 [==============================] - 3s 317us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 8/20
# 8848/8848 [==============================] - 3s 312us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 9/20
# 8848/8848 [==============================] - 3s 313us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 10/20
# 8848/8848 [==============================] - 3s 310us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 11/20
# 8848/8848 [==============================] - 3s 311us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 12/20
# 8848/8848 [==============================] - 3s 313us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 13/20
# 8848/8848 [==============================] - 3s 312us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 14/20
# 8848/8848 [==============================] - 3s 312us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 15/20
# 8848/8848 [==============================] - 3s 318us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 16/20
# 8848/8848 [==============================] - 3s 311us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 17/20
# 8848/8848 [==============================] - 3s 312us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 18/20
# 8848/8848 [==============================] - 3s 314us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 19/20
# 8848/8848 [==============================] - 3s 312us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 20/20
# 8848/8848 [==============================] - 3s 312us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# 33631/33631 [==============================] - 9s 276us/step
# ##################### Model model_gru_sgd Hours 168 ##################
#
#
# Skipped
# ##################### Model model_gru_rmsprop Hours 168 ##################
#
#
# Skipped
# ##################### Model model_rnn_adam Hours 168 ##################
#
#
# Train on 8848 samples, validate on 984 samples
# Epoch 1/20
# 8848/8848 [==============================] - 4s 414us/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 2/20
# 8848/8848 [==============================] - 1s 166us/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 3/20
# 8848/8848 [==============================] - 1s 164us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 4/20
# 8848/8848 [==============================] - 1s 162us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 5/20
# 8848/8848 [==============================] - 1s 162us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 6/20
# 8848/8848 [==============================] - 1s 167us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 7/20
# 8848/8848 [==============================] - 2s 170us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 8/20
# 8848/8848 [==============================] - 1s 165us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 9/20
# 8848/8848 [==============================] - 1s 164us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 10/20
# 8848/8848 [==============================] - 1s 162us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 11/20
# 8848/8848 [==============================] - 1s 166us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 12/20
# 8848/8848 [==============================] - 1s 165us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 13/20
# 8848/8848 [==============================] - 1s 168us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 14/20
# 8848/8848 [==============================] - 1s 167us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 15/20
# 8848/8848 [==============================] - 1s 168us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 16/20
# 8848/8848 [==============================] - 2s 183us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 17/20
# 8848/8848 [==============================] - 2s 176us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 18/20
# 8848/8848 [==============================] - 1s 167us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 19/20
# 8848/8848 [==============================] - 1s 165us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 20/20
# 8848/8848 [==============================] - 1s 164us/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# 33631/33631 [==============================] - 6s 183us/step
# ##################### Model model_rnn_sgd Hours 168 ##################
#
#
# Skipped
# ##################### Model model_rnn_rmsprop Hours 168 ##################
#
#
# Skipped

# %% [markdown]
# ## Results
#
#
# |hours|Mean Absolute Error |  loss function
# |--|--|
# |1  |  0.01328097059825935
# |10 |   0.016554366017757748
# | 24 | 0.02725420025859075
# | 50|  0.023748632413918377
# | 50 |    0.03477914220943476 | MSE
# | 1 |  0.042994678616862125
# | 1 |  0.016500973061146625
# | 48| 0.02513334271283482
# |48| 0.01888059062355331
# |72| 0.020766058881570845

# %%
|# import pandas as pd
# from sklearn.preprocessing import MinMaxScaler
# import tensorflow as tf


# y_train = train_y
# x_train = train_X

# y_test = test_y
# x_test = test_X

# EPOCHS = 10

# model = tf.keras.Sequential([
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(120, activation=tf.nn.relu),
#     tf.keras.layers.Dense(18, activation=tf.nn.relu),
#     tf.keras.layers.Dense(1, activation='linear')
# ])

# optimizer = tf.train.RMSPropOptimizer(0.001)

# model.compile(loss='mse',
#               optimizer=optimizer,
#               metrics=['mae'])


# # Store training stats
# import matplotlib.pyplot as plt


# def plot_history(history):
#     plt.figure()
#     plt.xlabel('Epoch')
#     plt.ylabel('Mean Abs Error ')
#     plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
#              label='Train Loss')
#     plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
#              label='Val loss')
#     plt.legend()
#     #plt.ylim([0, 0.2])


# #model.summary()
# history = model.fit(x_train, y_train, epochs=EPOCHS,
#                 validation_split=0.1, verbose=1)

# model.summary()

# plot_history(history)
# test_predictions = model.predict(x_test).flatten()
# test_acc, test_loss = model.evaluate(x_test, y_test)
# print(f"test accuracy: {test_acc}, test loss {test_loss}")

# %% [markdown]
# #Plot Predicted Values

# %%
# plt.figure(num=None, figsize=(20, 3), dpi=80, facecolor='w', edgecolor='k')
# plt.xlabel('Time')
# plt.ylabel('normalized value')
# plt.legend(('Original', 'Predicted'), loc='upper right')
# plt.plot(data[:,0], 'bo')
# plt.plot(np.concatenate([data[:n_train,0],test_predictions]), 'go')
# plt.legend(('Original', 'Predicted'), loc='upper right')
