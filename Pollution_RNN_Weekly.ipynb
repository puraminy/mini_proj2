# %% [markdown]
# <a href="https://colab.research.google.com/github/puraminy/mini_proj2/blob/master/Pollution_RNN_Weekly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load DATA

# %% [markdown]
# #### Data Main Source
# #####https://archive.ics.uci.edu/ml/datasets/Beijing+PM2.5+Data

# %%
# !git clone "https://github.com/puraminy/mini_proj2"
# Out:
# Cloning into 'mini_proj2'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 68 (delta 26), reused 9 (delta 1), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
import numpy as np
import pandas as pd

dataset_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"

#github = "https://raw.githubusercontent.com/puraminy/mini_proj2/master/polution.csv"

github = "mini_proj2/polution.csv"

c=pd.read_csv(github)
data=np.asarray(c)
print(data)
np.shape(data)
# Out:
# [[0.12977867 0.35294122 0.24590163 ... 0.00229001 0.         0.        ]
#  [0.14889336 0.36764708 0.24590163 ... 0.00381099 0.         0.        ]
#  [0.15995975 0.42647061 0.22950819 ... 0.00533197 0.         0.        ]
#  ...
#  [0.01006036 0.2647059  0.26229507 ... 0.40558836 0.         0.        ]
#  [0.01006036 0.2647059  0.26229507 ... 0.41399646 0.         0.        ]
#  [0.00804829 0.2647059  0.24590163 ... 0.42086649 0.         0.        ]]
# (43799, 8)

# %%
from matplotlib import pyplot
values = c.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(c.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %% [markdown]
# # Preparing Time Series

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot as plt
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# load dataset
def create_data(n_hours = 24, n_train = 10000):
  dataset = read_csv('mini_proj2/polution.csv', header=0)
  values = dataset.values
  
  print(np.shape(values))
  # integer encode direction
  encoder = LabelEncoder()
  values[:,4] = encoder.fit_transform(values[:,4])
  # ensure all data is float
  values = values.astype('float32')
  # normalize features
  # scaler = MinMaxScaler(feature_range=(0, 1))
  scaled = values # scaler.fit_transform(values)
  # specify the number of lag hours
  # n_hours = 24
  n_features = 8 
  # frame as supervised learning
  reframed = series_to_supervised(scaled, n_hours, 1)

 # print(reframed[:2])
 # print(reframed.shape)

  # split into train and test sets
  values = reframed.values
   #365 * 24
  train = values[:n_train, :]
  test = values[n_train:, :]
  # split into input and outputs
  n_obs = n_hours * n_features
  train_X, train_y = train[:, :n_obs], train[:, -n_features]

  test_X, test_y = test[:, :n_obs], test[:, -n_features]
  print(train_X.shape, len(train_X), train_y.shape)
  # reshape input to be 3D [samples, timesteps, features]
    
  train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
  test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
  print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
  
  return train_X,train_y, test_X, test_y

# %% [markdown]
# # Split Train & Test Data

# %%
def create_data2(n_hours = 24*7*8, n_train = 10000, step =1): # 8 week data
  c=pd.read_csv(github)
  data=np.asarray(c)

  print(np.shape(data))
  
  print(data.shape[0])
  n_test = data.shape[0]-n_train
  train = data[:n_train, :]
  test = data[n_train:n_train+n_test, :]

  train_X = np.zeros([n_train-n_hours, 8, 8]) # 8 week data
  for i in range (n_train-n_hours):
    for j in range (8): # 8 week data
      train_X[i, j, :] = train[i+(24*7)*j,:]
  train_y = train[n_hours:, 0]
  
  test_X = np.zeros([n_test-n_hours, 8, 8])
  for i in range (n_test-n_hours):
    for j in range (8): # 8 week data
      test_X[i, j, :] = test[i+(24*7)*j,:]
  test_y = test[n_hours:, 0]
  

  print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
  
  return train_X,train_y, test_X, test_y

def create_data3(n_records = 24, n_train = 10000, stride = 24*7): 
  n_train+=n_records
  c=pd.read_csv(github)
  data=np.asarray(c)

  print(np.shape(data))
  
  print(data.shape[0])
  n_test = data.shape[0]-n_train
  train = data[:n_train, :]
  test = data[n_train:n_train+n_test, :]

  n_items = n_records*stride

  train_X = np.zeros([n_train-n_items, n_records, 8])
  train_y = np.zeros([n_train-n_items, 1])
  
  
  for i in range (n_train-n_items):
      train_X[i,:,:] = train[i:i+n_items:stride,:]
      train_y[i] = train[i+n_items,0]

  test_X = np.zeros([n_test-n_items, n_records, 8])
  test_y = np.zeros([n_test-n_items, 1])
  for i in range (n_test-n_items):
      test_X[i,:,:] = test[i:i+n_items:stride,:]
      test_y[i] = test[i+n_items,0]

  print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
  
  return train_X,train_y, test_X, test_y

create_data3(n_records = 24, n_train = 10000, stride = 24*7)
# Out:
# (43799, 8)
# 43799
# (5992, 24, 8) (5992, 1) (29743, 24, 8) (29743, 1)
# (array([[[1.29778668e-01, 3.52941215e-01, 2.45901629e-01, ...,
#           2.29001138e-03, 0.00000000e+00, 0.00000000e+00],
#          [1.65995970e-01, 3.38235319e-01, 9.83606577e-02, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          [1.41851097e-01, 3.67647082e-01, 1.31147534e-01, ...,
#           3.79389944e-03, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.76056325e-01, 8.23529422e-01, 5.90163946e-01, ...,
#           2.29001138e-03, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 7.64705896e-01, 6.39344215e-01, ...,
#           6.10954501e-02, 0.00000000e+00, 0.00000000e+00],
#          [1.01609655e-01, 8.23529422e-01, 6.39344215e-01, ...,
#           2.29001138e-03, 0.00000000e+00, 0.00000000e+00]],
#
#         [[1.48893356e-01, 3.67647082e-01, 2.45901629e-01, ...,
#           3.81098920e-03, 0.00000000e+00, 0.00000000e+00],
#          [1.59959748e-01, 3.38235319e-01, 9.83606577e-02, ...,
#           4.58002277e-03, 0.00000000e+00, 0.00000000e+00],
#          [2.12273628e-01, 3.52941215e-01, 9.83606577e-02, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.82092547e-01, 8.23529422e-01, 5.90163946e-01, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 7.64705896e-01, 6.22950792e-01, ...,
#           6.26164302e-02, 0.00000000e+00, 0.00000000e+00],
#          [1.44869208e-01, 8.38235319e-01, 6.55737638e-01, ...,
#           5.34905633e-03, 0.00000000e+00, 0.00000000e+00]],
#
#         [[1.59959748e-01, 4.26470608e-01, 2.29508191e-01, ...,
#           5.33196656e-03, 0.00000000e+00, 0.00000000e+00],
#          [1.68008044e-01, 3.38235319e-01, 8.19672048e-02, ...,
#           7.63906771e-03, 0.00000000e+00, 0.00000000e+00],
#          [2.43460760e-01, 3.52941215e-01, 1.14754096e-01, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.75050288e-01, 8.23529422e-01, 5.90163946e-01, ...,
#           2.27292161e-03, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 7.50000000e-01, 6.06557369e-01, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          [1.60965785e-01, 8.38235319e-01, 6.39344215e-01, ...,
#           6.87003369e-03, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[8.14889297e-02, 7.35294163e-01, 7.54098296e-01, ...,
#           4.58002277e-03, 0.00000000e+00, 0.00000000e+00],
#          [2.16297776e-01, 8.67647052e-01, 8.03278685e-01, ...,
#           2.21481677e-02, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 5.44117689e-01, 6.55737638e-01, ...,
#           2.29001138e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [5.53319901e-02, 2.94117659e-01, 4.26229477e-01, ...,
#           5.34563810e-02, 0.00000000e+00, 0.00000000e+00],
#          [1.51911467e-01, 5.00000000e-01, 3.60655725e-01, ...,
#           1.22190900e-02, 0.00000000e+00, 0.00000000e+00],
#          [2.93762565e-01, 4.70588267e-01, 3.27868849e-01, ...,
#           2.29001138e-03, 0.00000000e+00, 0.00000000e+00]],
#
#         [[1.13682091e-01, 7.64705896e-01, 7.70491779e-01, ...,
#           9.92907863e-03, 0.00000000e+00, 0.00000000e+00],
#          [1.91146880e-01, 8.67647052e-01, 8.03278685e-01, ...,
#           3.05562690e-02, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 5.44117689e-01, 6.72131121e-01, ...,
#           3.13082151e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [3.82293761e-02, 2.94117659e-01, 4.26229477e-01, ...,
#           6.72135353e-02, 0.00000000e+00, 0.00000000e+00],
#          [9.65794772e-02, 4.70588267e-01, 3.60655725e-01, ...,
#           1.75681449e-02, 0.00000000e+00, 0.00000000e+00],
#          [2.90744454e-01, 4.70588267e-01, 3.44262272e-01, ...,
#           4.58002277e-03, 0.00000000e+00, 0.00000000e+00]],
#
#         [[9.75855067e-02, 7.64705896e-01, 7.70491779e-01, ...,
#           1.52781345e-02, 0.00000000e+00, 0.00000000e+00],
#          [2.37424538e-01, 8.67647052e-01, 8.03278685e-01, ...,
#           3.89643721e-02, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 5.44117689e-01, 6.72131121e-01, ...,
#           7.63906771e-03, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [3.31991948e-02, 3.23529422e-01, 4.09836054e-01, ...,
#           8.09706971e-02, 0.00000000e+00, 0.00000000e+00],
#          [6.84104636e-02, 4.55882370e-01, 3.44262272e-01, ...,
#           2.29172017e-02, 0.00000000e+00, 0.00000000e+00],
#          [2.73641855e-01, 4.70588267e-01, 3.60655725e-01, ...,
#           7.63906771e-03, 0.00000000e+00, 0.00000000e+00]]]),
#  array([[0.07042253],
#         [0.08953722],
#         [0.09859154],
#         ...,
#         [0.40845069],
#         [0.47183096],
#         [0.4114688 ]]),
#  array([[[3.99396360e-01, 5.44117689e-01, 4.59016383e-01, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          [3.21931578e-02, 3.38235319e-01, 4.42622930e-01, ...,
#           5.80534935e-02, 0.00000000e+00, 0.00000000e+00],
#          [1.71026159e-02, 3.08823556e-01, 5.08196712e-01, ...,
#           7.33316317e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [5.83500974e-02, 9.26470637e-01, 7.37704873e-01, ...,
#           2.21481677e-02, 0.00000000e+00, 0.00000000e+00],
#          [5.53319901e-02, 9.41176534e-01, 7.86885202e-01, ...,
#           3.51362936e-02, 0.00000000e+00, 0.00000000e+00],
#          [4.92957719e-02, 8.82352948e-01, 8.03278685e-01, ...,
#           3.66743580e-02, 0.00000000e+00, 0.00000000e+00]],
#
#         [[3.89335990e-01, 5.58823526e-01, 4.42622930e-01, ...,
#           2.27292161e-03, 0.00000000e+00, 0.00000000e+00],
#          [4.92957719e-02, 3.38235319e-01, 4.26229477e-01, ...,
#           7.02725872e-02, 0.00000000e+00, 0.00000000e+00],
#          [1.20724346e-02, 3.23529422e-01, 5.08196712e-01, ...,
#           8.86097625e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [6.13682084e-02, 9.11764741e-01, 7.37704873e-01, ...,
#           2.74972264e-02, 0.00000000e+00, 0.00000000e+00],
#          [6.23742417e-02, 9.41176534e-01, 7.86885202e-01, ...,
#           4.04853486e-02, 0.00000000e+00, 0.00000000e+00],
#          [5.03018089e-02, 8.97058845e-01, 7.86885202e-01, ...,
#           4.50824611e-02, 0.00000000e+00, 0.00000000e+00]],
#
#         [[3.98390323e-01, 5.44117689e-01, 4.09836054e-01, ...,
#           2.29001138e-03, 0.00000000e+00, 0.00000000e+00],
#          [4.02414463e-02, 3.97058845e-01, 4.09836054e-01, ...,
#           7.86806867e-02, 0.00000000e+00, 0.00000000e+00],
#          [1.20724346e-02, 3.38235319e-01, 5.08196712e-01, ...,
#           9.70178694e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [6.53923526e-02, 9.11764741e-01, 7.37704873e-01, ...,
#           3.28462794e-02, 0.00000000e+00, 0.00000000e+00],
#          [7.34406412e-02, 9.26470637e-01, 7.86885202e-01, ...,
#           4.73553836e-02, 0.00000000e+00, 0.00000000e+00],
#          [6.63983896e-02, 8.67647052e-01, 7.70491779e-01, ...,
#           5.19524962e-02, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[6.03621714e-02, 8.97058845e-01, 7.04918027e-01, ...,
#           4.12372909e-02, 0.00000000e+00, 5.55555560e-02],
#          [4.62776646e-02, 8.52941215e-01, 7.86885202e-01, ...,
#           1.29710333e-02, 0.00000000e+00, 0.00000000e+00],
#          [1.86116695e-01, 9.11764741e-01, 7.37704873e-01, ...,
#           3.82124260e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.40845068e-02, 3.52941215e-01, 3.11475396e-01, ...,
#           1.53533295e-01, 0.00000000e+00, 0.00000000e+00],
#          [2.03219309e-01, 3.67647082e-01, 2.62295067e-01, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          [2.31388323e-02, 3.82352948e-01, 3.44262272e-01, ...,
#           9.31897834e-02, 0.00000000e+00, 0.00000000e+00]],
#
#         [[7.04225302e-02, 8.82352948e-01, 7.04918027e-01, ...,
#           4.42963392e-02, 0.00000000e+00, 0.00000000e+00],
#          [4.32595573e-02, 8.67647052e-01, 8.03278685e-01, ...,
#           1.83200892e-02, 0.00000000e+00, 0.00000000e+00],
#          [2.00201198e-01, 9.11764741e-01, 7.21311450e-01, ...,
#           4.12714742e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.30784707e-02, 3.52941215e-01, 3.11475396e-01, ...,
#           1.68811440e-01, 0.00000000e+00, 0.00000000e+00],
#          [2.46478871e-01, 3.82352948e-01, 2.45901629e-01, ...,
#           2.27292161e-03, 0.00000000e+00, 0.00000000e+00],
#          [1.60965789e-02, 3.82352948e-01, 3.60655725e-01, ...,
#           1.01597890e-01, 0.00000000e+00, 0.00000000e+00]],
#
#         [[8.04828927e-02, 8.97058845e-01, 6.88524544e-01, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          [4.22535203e-02, 8.67647052e-01, 7.37704873e-01, ...,
#           7.51943968e-04, 0.00000000e+00, 0.00000000e+00],
#          [2.13279665e-01, 9.11764741e-01, 7.21311450e-01, ...,
#           4.43305150e-02, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.60965789e-02, 3.52941215e-01, 2.95081943e-01, ...,
#           1.84089556e-01, 0.00000000e+00, 0.00000000e+00],
#          [2.26358145e-01, 3.82352948e-01, 2.62295067e-01, ...,
#           3.79389944e-03, 0.00000000e+00, 0.00000000e+00],
#          [1.71026159e-02, 3.82352948e-01, 3.44262272e-01, ...,
#           1.11526966e-01, 0.00000000e+00, 0.00000000e+00]]]),
#  array([[0.        ],
#         [0.        ],
#         [0.        ],
#         ...,
#         [0.01006036],
#         [0.01006036],
#         [0.00804829]]))

# %% [markdown]
# # Model

# %%
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU, SimpleRNN

import tensorflow as tf
# GPU Processing
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at:{}'.format(device_name))

def create_model(cell_type = "normal", optimizer = 'adam'):
  if cell_type == "lstm":
    model = Sequential()
    model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1, activation='linear'))
  elif cell_type == "gru":
    model = Sequential()
    model.add(GRU(50, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1, activation='linear'))
  elif cell_type == "rnn":
    model = Sequential()
    model.add(SimpleRNN(50, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1, activation='linear'))
  else:
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(10))
#     model.add(Dense(20)) 
    model.add(Dense(10)) 
    model.add(Dense(1, activation='linear'))
  
  model.name = 'model_' + cell_type + '_' + optimizer
  if optimizer == 'rmsprop':
    optimizer = tf.train.RMSPropOptimizer(0.001)
    
#   model.compile(loss='mae', optimizer=optimizer)
  
  model.compile(loss='mae',
              optimizer=optimizer,
              metrics=['mae'])

  return model

n_train = 10000
n_hours = 24*7*8

train_X,train_y, test_X, test_y = create_data3(n_records = 8, n_train = 10000, stride = 24*7) # 8 weeks

model_normal_adam = create_model(optimizer='adam') #0
model_normal_sgd = create_model(optimizer='sgd') #1
model_normal_rmsprop = create_model(optimizer='rmsprop') #2

model_lstm_adam = create_model("lstm", 'adam') #3
model_lstm_sgd = create_model("lstm",'sgd') #4
model_lstm_rmsprop = create_model("lstm",'rmsprop') #5


model_gru_adam = create_model("gru", 'adam') #6
model_gru_sgd = create_model("gru", 'sgd') #7
model_gru_rmsprop = create_model("gru", 'rmsprop') #8


model_rnn_adam = create_model("rnn", 'adam') #9
model_rnn_sgd = create_model("rnn", 'sgd') #10
model_rnn_rmsprop = create_model("rnn", 'rmsprop') #11


models = [model_normal_adam, model_normal_sgd, model_normal_rmsprop,
          model_lstm_adam, model_lstm_sgd, model_lstm_rmsprop,
          model_gru_adam,model_gru_sgd, model_gru_rmsprop,
          model_rnn_adam, model_rnn_sgd, model_rnn_rmsprop]


Run = [0]*len(models)
Run[0] = 1
Run[3] = 1
Run[6] = 1
Run[9] = 1
EPOCHS =[20]*len(models)
model_index = 0

legends = []
silent = False

for model in models:

  # fit network
  model_name = model.name
  print(f"##################### Model {model_name} Hours {n_hours} ##################")
  print("\n")

  if not Run[model_index]:
    print("Skipped")
    model_index+=1
    continue

  legends.append(model_name)

  history = model.fit(train_X, train_y, 
                      epochs=EPOCHS[model_index], batch_size=72, 
#                       validation_data=(test_X, test_y), 
                      validation_split=0.1,
                      verbose=1, shuffle=True)
  # plot history
  if not silent: 
    plt.figure(0)
    plt.plot(history.history['loss'], label='train')
    plt.xlabel("Num of Epochs")
    plt.ylabel("Loss")
    plt.title("Training")
    plt.legend(legends)

    plt.figure(1)
    plt.plot(history.history['val_loss'], label='test')
    plt.xlabel("Num of Epochs")
    plt.ylabel("Loss")
    plt.title("Test")
    plt.legend(legends)

  test_predictions = model.predict(test_X).flatten()
  test_loss = model.evaluate(test_X, test_y)

  if not silent:
    plt.figure(num=model_index+2, figsize=(20, 3), dpi=80, facecolor='w', edgecolor='k')
    plt.title(f"Prediction of {model_name}")
    plt.xlabel('Time')
    plt.ylabel('normalized value')
    plt.legend(('Original', 'Predicted'), loc='upper right')
    plt.plot(data[:,0], 'bo')
    plt.plot(np.concatenate([data[:n_train,0],test_predictions]), 'go', alpha=0.4)
    plt.legend(('Original', 'Predicted'), loc='upper right')
    plt.savefig(model_name)

  model_index +=1


plt.show()
# Out:
# Found GPU at:/device:GPU:0
# (43799, 8)
# 43799
# (8664, 8, 8) (8664, 1) (32447, 8, 8) (32447, 1)
# ##################### Model model_normal_adam Hours 1344 ##################
#
#
# Train on 7797 samples, validate on 867 samples
# Epoch 1/20
# 7797/7797 [==============================] - 1s 187us/step - loss: 0.1455 - mean_absolute_error: 0.1455 - val_loss: 0.1193 - val_mean_absolute_error: 0.1193
# Epoch 2/20
# 7797/7797 [==============================] - 1s 77us/step - loss: 0.0746 - mean_absolute_error: 0.0746 - val_loss: 0.1110 - val_mean_absolute_error: 0.1110
# Epoch 3/20
# 7797/7797 [==============================] - 1s 79us/step - loss: 0.0672 - mean_absolute_error: 0.0672 - val_loss: 0.1047 - val_mean_absolute_error: 0.1047
# Epoch 4/20
# 7797/7797 [==============================] - 1s 78us/step - loss: 0.0652 - mean_absolute_error: 0.0652 - val_loss: 0.1059 - val_mean_absolute_error: 0.1059
# Epoch 5/20
# 7797/7797 [==============================] - 1s 76us/step - loss: 0.0645 - mean_absolute_error: 0.0645 - val_loss: 0.1082 - val_mean_absolute_error: 0.1082
# Epoch 6/20
# 7797/7797 [==============================] - 1s 78us/step - loss: 0.0638 - mean_absolute_error: 0.0638 - val_loss: 0.1137 - val_mean_absolute_error: 0.1137
# Epoch 7/20
# 7797/7797 [==============================] - 1s 77us/step - loss: 0.0632 - mean_absolute_error: 0.0632 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 8/20
# 7797/7797 [==============================] - 1s 76us/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.1046 - val_mean_absolute_error: 0.1046
# Epoch 9/20
# 7797/7797 [==============================] - 1s 77us/step - loss: 0.0630 - mean_absolute_error: 0.0630 - val_loss: 0.1026 - val_mean_absolute_error: 0.1026
# Epoch 10/20
# 7797/7797 [==============================] - 1s 76us/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.0964 - val_mean_absolute_error: 0.0964
# Epoch 11/20
# 7797/7797 [==============================] - 1s 79us/step - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.0901 - val_mean_absolute_error: 0.0901
# Epoch 12/20
# 7797/7797 [==============================] - 1s 78us/step - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.0966 - val_mean_absolute_error: 0.0966
# Epoch 13/20
# 7797/7797 [==============================] - 1s 78us/step - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.1119 - val_mean_absolute_error: 0.1119
# Epoch 14/20
# 7797/7797 [==============================] - 1s 79us/step - loss: 0.0627 - mean_absolute_error: 0.0627 - val_loss: 0.1096 - val_mean_absolute_error: 0.1096
# Epoch 15/20
# 7797/7797 [==============================] - 1s 77us/step - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.1194 - val_mean_absolute_error: 0.1194
# Epoch 16/20
# 7797/7797 [==============================] - 1s 79us/step - loss: 0.0623 - mean_absolute_error: 0.0623 - val_loss: 0.1019 - val_mean_absolute_error: 0.1019
# Epoch 17/20
# 7797/7797 [==============================] - 1s 77us/step - loss: 0.0621 - mean_absolute_error: 0.0621 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 18/20
# 7797/7797 [==============================] - 1s 77us/step - loss: 0.0623 - mean_absolute_error: 0.0623 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 19/20
# 7797/7797 [==============================] - 1s 78us/step - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.1161 - val_mean_absolute_error: 0.1161
# Epoch 20/20
# 7797/7797 [==============================] - 1s 76us/step - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# 32447/32447 [==============================] - 2s 54us/step
# ##################### Model model_normal_sgd Hours 1344 ##################
#
#
# Skipped
# ##################### Model model_normal_rmsprop Hours 1344 ##################
#
#
# Skipped
# ##################### Model model_lstm_adam Hours 1344 ##################
#
#
# Train on 7797 samples, validate on 867 samples
# Epoch 1/20
# 7797/7797 [==============================] - 4s 531us/step - loss: 0.0738 - mean_absolute_error: 0.0738 - val_loss: 0.0875 - val_mean_absolute_error: 0.0875
# Epoch 2/20
# 7797/7797 [==============================] - 3s 391us/step - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.0842 - val_mean_absolute_error: 0.0842
# Epoch 3/20
# 7797/7797 [==============================] - 3s 391us/step - loss: 0.0647 - mean_absolute_error: 0.0647 - val_loss: 0.0836 - val_mean_absolute_error: 0.0836
# Epoch 4/20
# 7797/7797 [==============================] - 3s 393us/step - loss: 0.0643 - mean_absolute_error: 0.0643 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940
# Epoch 5/20
# 7797/7797 [==============================] - 3s 396us/step - loss: 0.0639 - mean_absolute_error: 0.0639 - val_loss: 0.0931 - val_mean_absolute_error: 0.0931
# Epoch 6/20
# 7797/7797 [==============================] - 3s 394us/step - loss: 0.0637 - mean_absolute_error: 0.0637 - val_loss: 0.0934 - val_mean_absolute_error: 0.0934
# Epoch 7/20
# 7797/7797 [==============================] - 3s 395us/step - loss: 0.0639 - mean_absolute_error: 0.0639 - val_loss: 0.0893 - val_mean_absolute_error: 0.0893
# Epoch 8/20
# 7797/7797 [==============================] - 3s 392us/step - loss: 0.0634 - mean_absolute_error: 0.0634 - val_loss: 0.0913 - val_mean_absolute_error: 0.0913
# Epoch 9/20
# 7797/7797 [==============================] - 3s 393us/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.0931 - val_mean_absolute_error: 0.0931
# Epoch 10/20
# 7797/7797 [==============================] - 3s 392us/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.1014 - val_mean_absolute_error: 0.1014
# Epoch 11/20
# 7797/7797 [==============================] - 3s 394us/step - loss: 0.0630 - mean_absolute_error: 0.0630 - val_loss: 0.0904 - val_mean_absolute_error: 0.0904
# Epoch 12/20
# 7797/7797 [==============================] - 3s 393us/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 13/20
# 7797/7797 [==============================] - 3s 393us/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0843 - val_mean_absolute_error: 0.0843
# Epoch 14/20
# 7797/7797 [==============================] - 3s 392us/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.0823 - val_mean_absolute_error: 0.0823
# Epoch 15/20
# 7797/7797 [==============================] - 3s 390us/step - loss: 0.0629 - mean_absolute_error: 0.0629 - val_loss: 0.0847 - val_mean_absolute_error: 0.0847
# Epoch 16/20
# 7797/7797 [==============================] - 3s 395us/step - loss: 0.0627 - mean_absolute_error: 0.0627 - val_loss: 0.0845 - val_mean_absolute_error: 0.0845
# Epoch 17/20
# 7797/7797 [==============================] - 3s 394us/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.0908 - val_mean_absolute_error: 0.0908
# Epoch 18/20
# 7797/7797 [==============================] - 3s 400us/step - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923
# Epoch 19/20
# 7797/7797 [==============================] - 3s 394us/step - loss: 0.0619 - mean_absolute_error: 0.0619 - val_loss: 0.0836 - val_mean_absolute_error: 0.0836
# Epoch 20/20
# 7797/7797 [==============================] - 3s 392us/step - loss: 0.0623 - mean_absolute_error: 0.0623 - val_loss: 0.0903 - val_mean_absolute_error: 0.0903
# 32447/32447 [==============================] - 11s 336us/step
# ##################### Model model_lstm_sgd Hours 1344 ##################
#
#
# Skipped
# ##################### Model model_lstm_rmsprop Hours 1344 ##################
#
#
# Skipped
# ##################### Model model_gru_adam Hours 1344 ##################
#
#
# Train on 7797 samples, validate on 867 samples
# Epoch 1/20
# 7797/7797 [==============================] - 4s 475us/step - loss: 0.0678 - mean_absolute_error: 0.0678 - val_loss: 0.0862 - val_mean_absolute_error: 0.0862
# Epoch 2/20
# 7797/7797 [==============================] - 3s 336us/step - loss: 0.0650 - mean_absolute_error: 0.0650 - val_loss: 0.0864 - val_mean_absolute_error: 0.0864
# Epoch 3/20
# 7797/7797 [==============================] - 3s 336us/step - loss: 0.0643 - mean_absolute_error: 0.0643 - val_loss: 0.0863 - val_mean_absolute_error: 0.0863
# Epoch 4/20
# 7797/7797 [==============================] - 3s 338us/step - loss: 0.0650 - mean_absolute_error: 0.0650 - val_loss: 0.0917 - val_mean_absolute_error: 0.0917
# Epoch 5/20
# 7797/7797 [==============================] - 3s 340us/step - loss: 0.0639 - mean_absolute_error: 0.0639 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 6/20
# 7797/7797 [==============================] - 3s 337us/step - loss: 0.0635 - mean_absolute_error: 0.0635 - val_loss: 0.0884 - val_mean_absolute_error: 0.0884
# Epoch 7/20
# 7797/7797 [==============================] - 3s 335us/step - loss: 0.0636 - mean_absolute_error: 0.0636 - val_loss: 0.0861 - val_mean_absolute_error: 0.0861
# Epoch 8/20
# 7797/7797 [==============================] - 3s 334us/step - loss: 0.0639 - mean_absolute_error: 0.0639 - val_loss: 0.0882 - val_mean_absolute_error: 0.0882
# Epoch 9/20
# 7797/7797 [==============================] - 3s 336us/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.0869 - val_mean_absolute_error: 0.0869
# Epoch 10/20
# 7797/7797 [==============================] - 3s 334us/step - loss: 0.0632 - mean_absolute_error: 0.0632 - val_loss: 0.0894 - val_mean_absolute_error: 0.0894
# Epoch 11/20
# 7797/7797 [==============================] - 3s 333us/step - loss: 0.0634 - mean_absolute_error: 0.0634 - val_loss: 0.0869 - val_mean_absolute_error: 0.0869
# Epoch 12/20
# 7797/7797 [==============================] - 3s 329us/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0887 - val_mean_absolute_error: 0.0887
# Epoch 13/20
# 7797/7797 [==============================] - 3s 332us/step - loss: 0.0630 - mean_absolute_error: 0.0630 - val_loss: 0.0845 - val_mean_absolute_error: 0.0845
# Epoch 14/20
# 7797/7797 [==============================] - 3s 329us/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.0811 - val_mean_absolute_error: 0.0811
# Epoch 15/20
# 7797/7797 [==============================] - 3s 328us/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.0845 - val_mean_absolute_error: 0.0845
# Epoch 16/20
# 7797/7797 [==============================] - 3s 331us/step - loss: 0.0623 - mean_absolute_error: 0.0623 - val_loss: 0.0823 - val_mean_absolute_error: 0.0823
# Epoch 17/20
# 7797/7797 [==============================] - 3s 329us/step - loss: 0.0623 - mean_absolute_error: 0.0623 - val_loss: 0.0975 - val_mean_absolute_error: 0.0975
# Epoch 18/20
# 7797/7797 [==============================] - 3s 331us/step - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.0844 - val_mean_absolute_error: 0.0844
# Epoch 19/20
# 7797/7797 [==============================] - 3s 334us/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0921 - val_mean_absolute_error: 0.0921
# Epoch 20/20
# 7797/7797 [==============================] - 3s 331us/step - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# 32447/32447 [==============================] - 10s 297us/step
# ##################### Model model_gru_sgd Hours 1344 ##################
#
#
# Skipped
# ##################### Model model_gru_rmsprop Hours 1344 ##################
#
#
# Skipped
# ##################### Model model_rnn_adam Hours 1344 ##################
#
#
# Train on 7797 samples, validate on 867 samples
# Epoch 1/20
# 7797/7797 [==============================] - 2s 295us/step - loss: 0.0872 - mean_absolute_error: 0.0872 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 2/20
# 7797/7797 [==============================] - 1s 170us/step - loss: 0.0661 - mean_absolute_error: 0.0661 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 3/20
# 7797/7797 [==============================] - 1s 172us/step - loss: 0.0656 - mean_absolute_error: 0.0656 - val_loss: 0.0915 - val_mean_absolute_error: 0.0915
# Epoch 4/20
# 7797/7797 [==============================] - 1s 171us/step - loss: 0.0646 - mean_absolute_error: 0.0646 - val_loss: 0.0984 - val_mean_absolute_error: 0.0984
# Epoch 5/20
# 7797/7797 [==============================] - 1s 173us/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0933 - val_mean_absolute_error: 0.0933
# Epoch 6/20
# 7797/7797 [==============================] - 1s 174us/step - loss: 0.0630 - mean_absolute_error: 0.0630 - val_loss: 0.0871 - val_mean_absolute_error: 0.0871
# Epoch 7/20
# 7797/7797 [==============================] - 1s 170us/step - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.0859 - val_mean_absolute_error: 0.0859
# Epoch 8/20
# 7797/7797 [==============================] - 1s 169us/step - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.1101 - val_mean_absolute_error: 0.1101
# Epoch 9/20
# 7797/7797 [==============================] - 1s 170us/step - loss: 0.0620 - mean_absolute_error: 0.0620 - val_loss: 0.0850 - val_mean_absolute_error: 0.0850
# Epoch 10/20
# 7797/7797 [==============================] - 1s 171us/step - loss: 0.0638 - mean_absolute_error: 0.0638 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 11/20
# 7797/7797 [==============================] - 1s 168us/step - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
# Epoch 12/20
# 7797/7797 [==============================] - 1s 170us/step - loss: 0.0609 - mean_absolute_error: 0.0609 - val_loss: 0.0852 - val_mean_absolute_error: 0.0852
# Epoch 13/20
# 7797/7797 [==============================] - 1s 172us/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0913 - val_mean_absolute_error: 0.0913
# Epoch 14/20
# 7797/7797 [==============================] - 1s 170us/step - loss: 0.0608 - mean_absolute_error: 0.0608 - val_loss: 0.0874 - val_mean_absolute_error: 0.0874
# Epoch 15/20
# 7797/7797 [==============================] - 1s 171us/step - loss: 0.0606 - mean_absolute_error: 0.0606 - val_loss: 0.0863 - val_mean_absolute_error: 0.0863
# Epoch 16/20
# 7797/7797 [==============================] - 1s 173us/step - loss: 0.0598 - mean_absolute_error: 0.0598 - val_loss: 0.1048 - val_mean_absolute_error: 0.1048
# Epoch 17/20
# 7797/7797 [==============================] - 1s 170us/step - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.1044 - val_mean_absolute_error: 0.1044
# Epoch 18/20
# 7797/7797 [==============================] - 1s 170us/step - loss: 0.0589 - mean_absolute_error: 0.0589 - val_loss: 0.1004 - val_mean_absolute_error: 0.1004
# Epoch 19/20
# 7797/7797 [==============================] - 1s 174us/step - loss: 0.0598 - mean_absolute_error: 0.0598 - val_loss: 0.0897 - val_mean_absolute_error: 0.0897
# Epoch 20/20
# 7797/7797 [==============================] - 1s 171us/step - loss: 0.0588 - mean_absolute_error: 0.0588 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# 32447/32447 [==============================] - 6s 189us/step
# ##################### Model model_rnn_sgd Hours 1344 ##################
#
#
# Skipped
# ##################### Model model_rnn_rmsprop Hours 1344 ##################
#
#
# Skipped

# %% [markdown]
# ## Results
#
#
# |hours|Mean Absolute Error |  loss function
# |--|--|
# |1  |  0.01328097059825935
# |10 |   0.016554366017757748
# | 24 | 0.02725420025859075
# | 50|  0.023748632413918377
# | 50 |    0.03477914220943476 | MSE
# | 1 |  0.042994678616862125
# | 1 |  0.016500973061146625
# | 48| 0.02513334271283482
# |48| 0.01888059062355331
# |72| 0.020766058881570845

# %%
  test_loss = model.evaluate(test_X, test_y)
  print("test loss:", test_loss)
# import pandas as pd
# from sklearn.preprocessing import MinMaxScaler
# import tensorflow as tf


# y_train = train_y
# x_train = train_X

# y_test = test_y
# x_test = test_X

# EPOCHS = 10

# model = tf.keras.Sequential([
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(120, activation=tf.nn.relu),
#     tf.keras.layers.Dense(18, activation=tf.nn.relu),
#     tf.keras.layers.Dense(1, activation='linear')
# ])

# optimizer = tf.train.RMSPropOptimizer(0.001)

# model.compile(loss='mse',
#               optimizer=optimizer,
#               metrics=['mae'])


# # Store training stats
# import matplotlib.pyplot as plt


# def plot_history(history):
#     plt.figure()
#     plt.xlabel('Epoch')
#     plt.ylabel('Mean Abs Error ')
#     plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
#              label='Train Loss')
#     plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
#              label='Val loss')
#     plt.legend()
#     #plt.ylim([0, 0.2])


# #model.summary()
# history = model.fit(x_train, y_train, epochs=EPOCHS,
#                 validation_split=0.1, verbose=1)

# model.summary()

# plot_history(history)
# test_predictions = model.predict(x_test).flatten()
# test_acc, test_loss = model.evaluate(x_test, y_test)
# print(f"test accuracy: {test_acc}, test loss {test_loss}")
# Out:
# 32447/32447 [==============================] - 7s 201us/step
# test loss: [0.22901513868211565, 0.22901513868211565]

# %% [markdown]
# #Plot Predicted Values

# %%
# plt.figure(num=None, figsize=(20, 3), dpi=80, facecolor='w', edgecolor='k')
# plt.xlabel('Time')
# plt.ylabel('normalized value')
# plt.legend(('Original', 'Predicted'), loc='upper right')
# plt.plot(data[:,0], 'bo')
# plt.plot(np.concatenate([data[:n_train,0],test_predictions]), 'go')
# plt.legend(('Original', 'Predicted'), loc='upper right')
